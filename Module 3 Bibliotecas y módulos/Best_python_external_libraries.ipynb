# %% [markdown]
# ## WEB DEVELOPMENT
# #### Useful for web applications (e-commerce platform, social networking site...)
#     > Flask
#     > Django
# #### Simplifies HTTP Request   (APIs, fetching data from the web...)
#     > Request

# %% [markdown]
# ## DATA SCIENCE
# #### For data scientific computing, machine-learning
#     > Numpy
# #### For data analysis (manipulate, clean, analyze data, CSV...)
#     > Pandas
# #### Visualization library
#     > Matpotlib

# %% [markdown]
# ## MACHINE LEARNING
#     > Scikit learn
# #### Deep learning libraries
#     > Microsoft Cognitive Toolkit
#     > PyTorch
#     > Keras

# %% [markdown]
# ## Installing an external library
#     1. Open your terminal or command prompt to access the system's command-line interface.
#     2. Enter: pip install library_name  (Replace library_name with the library name u want to install)
#     3. Hit Enter :P
